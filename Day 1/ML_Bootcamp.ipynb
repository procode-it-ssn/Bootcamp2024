# %%
pd=datasets.load_diabetes(return_X_y=True)
#taking 1st feature

X=pd[0][:,np.newaxis,2]
Y=pd[1]

# %%
from sklearn import datasets
import pandas as pd
import numpy as np

# %%
print('Dimension of the Data',X.shape)
print('Dimesntion of the Label',Y.shape)
# Out:
# Dimension of the Data (442, 1)
# Dimesntion of the Label (442,)

# %%
#@title Import CSV from pandas.

import pandas as pd
df = pd.read_csv('/content/insurance_data.csv')

# %% [markdown]
# https://github.com/Harish-Arun/ML-Practice/blob/main/Sample_pd.ipynb
#
# Refer this for importing CSV files into Pandas dataframe.

# %%
#@title Train-Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)
print('Dimension of the Train set',X_train.shape)
print('Dimension of the Test set',X_test.shape)
# Out:
# Dimension of the Train set (331, 1)
# Dimension of the Test set (111, 1)

# %%
#@title Linear Regression
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)

prediction=lr.predict(X_test)

from sklearn.metrics import mean_squared_error,r2_score
print("Coefficient: ",lr.coef_)
print("MSE ",mean_squared_error(Y_test,prediction))
print("Coefficient of determination: ",r2_score(Y_test,prediction))
# Out:
# Coefficient:  [923.32558425]
# MSE  3567.2286122185255
# Coefficient of determination:  0.35579864987530185

# %%
#@title Metrics

from sklearn.metrics import mean_squared_error,r2_score
print("Coefficient: ",lr.coef_)
print("MSE ",mean_squared_error(Y_test,prediction))
print("Coefficient of determination: ",r2_score(Y_test,prediction))
# Out:
# Coefficient:  [923.32558425]
# MSE  3567.2286122185255
# Coefficient of determination:  0.35579864987530185

# %%
#@title Plot

plt.scatter(X_test,Y_test,color="blue")
plt.plot(X_test,prediction,color="red",linewidth=3)

# %% [markdown]
# The Iris Dataset will have
# <br>
# <ul>
# <li>X[0]= 'sepal length'</li>
# <li>X[1]= 'sepal width' </li>
# <li>X[2]='petal length' </li>
# <li>X[3]='petal width'</li>
# </ul>
# <br>
# Y= 'species'

# %%
iris=datasets.load_iris()
X=iris.data[:,:2]
y=iris.target

# %%
#@title Train-Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y)
print('Dimension of the Train set',X_train.shape)
print('Dimension of the Test set',X_test.shape)
print('Types of Classes', np.unique(y))
# Out:
# Dimension of the Train set (112, 2)
# Dimension of the Test set (38, 2)
# Types of Classes [0 1 2]

# %%
#@title Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression(C=1)
logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1)

# %%
#@title Plot
from sklearn.inspection import DecisionBoundaryDisplay
DecisionBoundaryDisplay.from_estimator(logreg,X)
plt.scatter(X[:,0],X[:,1],c=y,edgecolors="k")

# %%
#@title Metrics
pred=logreg.predict(X_test)


from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

print("Accuracy Score: ",accuracy_score(Y_test,pred))
print('Classification Report: \n',classification_report(Y_test,pred))

print("Confusion Matrix :\n",confusion_matrix(Y_test,pred))
# Out:
# Accuracy Score:  0.7894736842105263
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.50      0.62      0.56         8
#            2       0.79      0.69      0.73        16
#
#     accuracy                           0.79        38
#    macro avg       0.76      0.77      0.76        38
# weighted avg       0.80      0.79      0.79        38
#
# Confusion Matrix :
#  [[14  0  0]
#  [ 0  5  3]
#  [ 0  5 11]]

# %%
#@title Load Dataset
from sklearn import datasets

iris=datasets.load_iris()
X=iris.data
Y=iris.target


from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
#@title Decision Tree
from sklearn.tree import DecisionTreeClassifier

DTC=DecisionTreeClassifier(max_leaf_nodes=3,random_state=0)
DTC.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3, random_state=0)

# %%
#@title Tree Plot
from sklearn import tree
tree.plot_tree(DTC)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.667\nsamples = 105\nvalue = [35, 35, 35]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 70\nvalue = [0, 35, 35]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.184\nsamples = 39\nvalue = [0, 35, 4]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

# %%
#@title Metrics
pred=DTC.predict(X_test)


from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

print("Accuracy Score: ",accuracy_score(Y_test,pred))
print('Classification Report: \n',classification_report(Y_test,pred))

print("Confusion Matrix :\n",confusion_matrix(Y_test,pred))
# Out:
# Accuracy Score:  0.9555555555555556
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.93      0.93      0.93        15
#            2       0.93      0.93      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# Confusion Matrix :
#  [[15  0  0]
#  [ 0 14  1]
#  [ 0  1 14]]

# %%
#@title Random Forest
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
#@title Metrics
pred=clf.predict(X_test)


from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

print("Accuracy Score: ",accuracy_score(Y_test,pred))
print('Classification Report: \n',classification_report(Y_test,pred))

print("Confusion Matrix :\n",confusion_matrix(Y_test,pred))
# Out:
# Accuracy Score:  0.9555555555555556
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.93      0.93      0.93        15
#            2       0.93      0.93      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# Confusion Matrix :
#  [[15  0  0]
#  [ 0 14  1]
#  [ 0  1 14]]

# %%
#@title SVM
from sklearn.svm import SVC
clf=SVC(kernel="linear")
clf.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
#@title Metrics
pred=clf.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

print("Accuracy Scores ",accuracy_score(Y_test,pred))
print("Classification Report\n",classification_report(Y_test,pred))
print("Confusion Matrix\n",confusion_matrix(Y_test,pred))
# Out:
# Accuracy Scores  0.9777777777777777
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      0.93      0.97        15
#            2       0.94      1.00      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# Confusion Matrix
#  [[15  0  0]
#  [ 0 14  1]
#  [ 0  0 15]]

# %%
#@title KNN
#Import Random Forest Model
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
#@title Metrics
pred=knn.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

print("Accuracy Scores ",accuracy_score(Y_test,pred))
print("Classification Report\n",classification_report(Y_test,pred))
print("Confusion Matrix\n",confusion_matrix(Y_test,pred))
# Out:
# Accuracy Scores  0.9555555555555556
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.93      0.93      0.93        15
#            2       0.93      0.93      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
# Confusion Matrix
#  [[15  0  0]
#  [ 0 14  1]
#  [ 0  1 14]]

# %% [markdown]
# <h1>Exercise.</h1>
# Now use sklearn.load_digits() dataset, <br>load_breast_cancer()
# <br>
#
# Implement all the above classification model for these dataset.
